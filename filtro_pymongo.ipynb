# %%
from pymongo import MongoClient

# %%
client = MongoClient()

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = client.get_database("lab")

# %%
#me quedo con 10 compañias que tienen alguna oficina en Seattle, ya que si no ponía un limite demasiadas.
lista = list(db.companies.find({"offices.city":"Seattle"},{"name":1,"offices":1}).limit(10))

len(lista)
# Out:
# 10

# %%
lista
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675297d8a'),
#   'name': 'Wetpaint',
#   'offices': [{'description': '',
#     'address1': '710 - 2nd Avenue',
#     'address2': 'Suite 1100',
#     'zip_code': '98104',
#     'city': 'Seattle',
#     'state_code': 'WA',
#     'country_code': 'USA',
#     'latitude': 47.603122,
#     'longitude': -122.333253},
#    {'description': '',
#     'address1': '270 Lafayette Street',
#     'address2': 'Suite 505',
#     'zip_code': '10012',
#     'city': 'New York',
#     'state_code': 'NY',
#     'country_code': 'USA',
#     'latitude': 40.7237306,
#     'longitude': -73.9964312}]},
#  {'_id': ObjectId('52cdef7c4bab8bd675297dba'),
#   'name': 'Google',
#   'offices': [{'description': 'Google Headquarters',
#     'address1': '1600 Amphitheatre Parkway',
#     'address2': '',
#     'zip_code': '',
#     'city': 'Mountain View',
#     'state_code': 'CA',
#     'country_code': 'USA',
#     'latitude': 37.421972,
#     'longitude': -122.084143},
# ...
